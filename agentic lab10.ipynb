# %% [markdown]
# <a href="https://colab.research.google.com/github/minbot616/Agentic-AI-Lab/blob/main/agenticailab10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain langchain-community langchain-groq duckduckgo-search ddgs -q

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(api_key="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",

               model="llama-3.1-8b-instant", temperature=0.3)

# %%
from langchain_community.tools import DuckDuckGoSearchResults

search = DuckDuckGoSearchResults()



def search_agent(topic):

    return search.run(f'latest news about {topic}')

# %%
def summariser_agent(raw_results):

    return llm.invoke(

        'Summarise these news results into 3 short bullet points:\n'

        + raw_results).content

# %%
def report_agent(topic, summary):

    return llm.invoke(

        f'Create a short Markdown report titled "News: {topic}". '

        f'Use a heading and these points:\n{summary}').content

# %%
topic = 'artificial intelligence'



raw = search_agent(topic)          # Agent 1

summary = summariser_agent(raw)    # Agent 2

report = report_agent(topic, summary)  # Agent 3



with open('news_report.md', 'w') as f:

    f.write(report)



print(report)

print('\nSaved as news_report.md (see the Files panel on the left).')
# Out:
# # News: Artificial Intelligence
#
# Here are 3 short bullet points summarizing the latest news results:
#
# * AI Weekly provides curated AI updates 3 times a week, covering funding, models, regulation, and applications, and has been read by over 44,000 professionals since 2015.
# * AI News delivers the latest updates in artificial intelligence, machine learning, deep learning, enterprise AI, and emerging tech worldwide.
# * Reuters offers the latest artificial intelligence news, covering breakthroughs, technology trends, regulation, ethics, business, and global impact.
#
# Saved as news_report.md (see the Files panel on the left).
